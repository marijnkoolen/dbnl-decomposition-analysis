# %%
import re
import pandas as pd

publication_file = '../metadata/DBNL 20241212 Proza 19e en 20e eeuw met subgenres.xlsx'
pub_df = pd.read_excel(publication_file)

# %% [markdown]
# ## Preprocessing

# %%
def extract_author_id(title_id):
    if title_id.startswith('_'):
        return None
    if m := re.match(r"^(\w+\d+)(\w+\d+)", title_id):
        author_id = m.group(1)
    else:
        print('unexpected title_id format:', title)
    return author_id


def extract_year(jaar):
    jaar = jaar.strip()
    year_start, year_end, precision = None, None, None
    if m := re.match(r"^\d{4}$", jaar):
        year_start = int(jaar)
        year_end = year_start
        precision = 'exact'
    elif m := re.match(r"^(\d{4})-(\d{4})$", jaar):
        year_start = int(m.group(1))
        year_end = int(m.group(2))
        precision = 'exact'
    elif m := re.match(r"^ca\. (\d{4})$", jaar):
        year_start = int(m.group(1))
        year_end = year_start
        precision = 'circa'
    elif m := re.match(r"^ca\. (\d{4})\?$", jaar):
        year_start = int(m.group(1))
        year_end = year_start
        precision = 'circa'
    elif m := re.match(r"^na (\d{4})$", jaar):
        year_start = int(m.group(1))
        year_end = year_start
        precision = 'after'
    elif m := re.match(r"^ca\. (\d{4})-(\d{4})$", jaar):
        year_start = int(m.group(1))
        year_end = int(m.group(2))
        precision = 'circa'
    else:
        print(f"#{jaar}#")
    return year_start, year_end, precision

pub_df['author_id'] = pub_df.ti_id.apply(extract_author_id)
pub_df.author_id
pub_df['year_start'], pub_df['year_end'], pub_df['year_precision'] = zip(*pub_df.jaar.apply(extract_year))
pub_df['decade_start'] = pub_df.year_start.apply(lambda x: int(x/10) * 10)
pub_df['decade_end'] = pub_df.year_end.apply(lambda x: int(x/10) * 10)

pub_df
# Out:
#               ti_id                                              titel  \
# 0     woen003lant04                              De Lantaarn voor 1800
# 1     kist001leve01  Het leven, gevoelens en zonderlinge reize van ...
# 2     woen003lant05                              De Lantaarn voor 1801
# 3     simo001verh01                                     Verhandelingen
# 4     simo001verh01                                     Verhandelingen
# ...             ...                                                ...
# 5723  slor001frik01                                    Fri-kontren-sma
# 5724  aard002stij01  Stijfkopje omnibus (onder pseudoniem Ankie Aal...
# 5725  gras003daar01                               Daar ga je, Claudia!
# 5726  nijn001tolh02                         Tolhuis "Het zwarte paard"
# 5727  bosm029toch02                                       Tochtgenoten
#
#                jaar       druk categorie voornaam voorvoegsel  \
# 0              1800  1ste druk      werk   Pieter         van
# 1              1800  1ste druk      werk   Willem         NaN
# 2              1801  1ste druk      werk   Pieter         van
# 3              1802  1ste druk      werk    Arend         NaN
# 4              1802  1ste druk      werk    Arend         NaN
# ...             ...        ...       ...      ...         ...
# 5723       ca. 1970  1ste druk      werk  Michaël         NaN
# 5724       ca. 1970    herdruk   herdruk     H.P.     van den
# 5725  ca. 1970-1980          ?      werk      Cok         NaN
# 5726        na 1941    herdruk   herdruk     H.J.         van
# 5727        na 1970   2de druk   herdruk    Nanne         NaN
#
#                 achternaam                    uitgever  plaats_van_uitgave  \
# 0                  Woensel                         NaN                 NaN
# 1                     Kist                         NaN             Haarlem
# 2                  Woensel                         NaN                 NaN
# 3            Fokke Simonsz       Johannes van der Heij           Amsterdam
# 4            Fokke Simonsz       Johannes van der Heij           Amsterdam
# ...                    ...                         ...                 ...
# 5723                 Slory                        Z.n.                z.p.
# 5724               Aardweg                        Geka  Alphen aan de Rijn
# 5725              Grashoff  Het Goede Boek / Standaard  Huizen / Antwerpen
# 5726  Nijnatten-Doffegnies               Westfriesland               Hoorn
# 5727                 Bosma             G.F. Callenbach                 NaN
#
#       ...  genre                     subgenre         geplaatst  \
# 0     ...  proza       tijdschrift / jaarboek  woen003lant04_01
# 1     ...  proza                        roman  kist001leve01_01
# 2     ...  proza       tijdschrift / jaarboek  woen003lant05_01
# 3     ...  proza          lezing / voordracht  simo001verh01_01
# 4     ...  proza  non-fictie/filosofie-ethiek  simo001verh01_01
# ...   ...    ...                          ...               ...
# 5723  ...  proza      gedichten / dichtbundel  slor001frik01_01
# 5724  ...  proza                   novelle(n)  aard002stij01_01
# 5725  ...  proza                        roman  gras003daar01_01
# 5726  ...  proza                        roman  nijn001tolh02_01
# 5727  ...  proza                        roman  bosm029toch02_01
#
#                                link naar DBNL.org author_id year_start  \
# 0     https://www.dbnl.org/tekst/woen003lant04_01   woen003       1800
# 1     https://www.dbnl.org/tekst/kist001leve01_01   kist001       1800
# 2     https://www.dbnl.org/tekst/woen003lant05_01   woen003       1801
# 3     https://www.dbnl.org/tekst/simo001verh01_01   simo001       1802
# 4     https://www.dbnl.org/tekst/simo001verh01_01   simo001       1802
# ...                                           ...       ...        ...
# 5723  https://www.dbnl.org/tekst/slor001frik01_01   slor001       1970
# 5724  https://www.dbnl.org/tekst/aard002stij01_01   aard002       1970
# 5725  https://www.dbnl.org/tekst/gras003daar01_01   gras003       1970
# 5726  https://www.dbnl.org/tekst/nijn001tolh02_01   nijn001       1941
# 5727  https://www.dbnl.org/tekst/bosm029toch02_01   bosm029       1970
#
#       year_end  year_precision decade_start  decade_end
# 0         1800           exact         1800        1800
# 1         1800           exact         1800        1800
# 2         1801           exact         1800        1800
# 3         1802           exact         1800        1800
# 4         1802           exact         1800        1800
# ...        ...             ...          ...         ...
# 5723      1970           circa         1970        1970
# 5724      1970           circa         1970        1970
# 5725      1980           circa         1970        1980
# 5726      1941           after         1940        1940
# 5727      1970           after         1970        1970
#
# [5728 rows x 21 columns]

# %%
pub_df.genre.value_counts()
# Out:
# genre
# proza    5728
# Name: count, dtype: int64

# %%
s = pub_df.ti_id.value_counts()
s = s[s > 1]
pub_df[pub_df.ti_id.isin(s.index)].sort_values('ti_id')
# Out:
#               ti_id                                  titel           jaar  \
# 5493  _alp001alph01  Alphabet tot nut en vermaak der jeugd  ca. 1850-1860
# 5494  _alp001alph01  Alphabet tot nut en vermaak der jeugd  ca. 1850-1860
# 1164  _alv001190001                  Alvoorder. Jaargang 1      1900-1901
# 1163  _alv001190001                  Alvoorder. Jaargang 1      1900-1901
# 1162  _alv001190001                  Alvoorder. Jaargang 1      1900-1901
# ...             ...                                    ...            ...
# 4477  zout002gesc01             Het geschenk van Watramama           1980
# 2965  zuyl002gesc01            De geschiedenis van Caliste           1942
# 2966  zuyl002gesc01            De geschiedenis van Caliste           1942
# 4326  zuyl002rebe01                  Rebels en beminnelijk           1978
# 4325  zuyl002rebe01                  Rebels en beminnelijk           1978
#
#            druk categorie voornaam voorvoegsel  \
# 5493   4de druk   herdruk  Anoniem         NaN
# 5494   4de druk   herdruk  Anoniem         NaN
# 1164  1ste druk      werk      NaN         NaN
# 1163  1ste druk      werk      NaN         NaN
# 1162  1ste druk      werk      NaN         NaN
# ...         ...       ...      ...         ...
# 4477  1ste druk      werk       H.         NaN
# 2965  1ste druk   uitgave    Belle         van
# 2966  1ste druk   uitgave    Belle         van
# 4326   3de druk   herdruk    Belle         van
# 4325   3de druk   herdruk    Belle         van
#
#                                   achternaam                        uitgever  \
# 5493  Alphabet tot nut en vermaak der jeugd                  H.T. Hendriksen
# 5494  Alphabet tot nut en vermaak der jeugd                  H.T. Hendriksen
# 1164                 [tijdschrift] Alvoorder                            Z.n.
# 1163                 [tijdschrift] Alvoorder                            Z.n.
# 1162                 [tijdschrift] Alvoorder                            Z.n.
# ...                                      ...                             ...
# 4477                              Zoutendijk  Stichting Kinderkrant Suriname
# 2965                                  Zuylen                            Veen
# 2966                                  Zuylen                            Veen
# 4326                                  Zuylen                De Arbeiderspers
# 4325                                  Zuylen                De Arbeiderspers
#
#      plaats_van_uitgave  ...  genre                 subgenre  \
# 5493          Rotterdam  ...  proza  plaatwerk / prentenboek
# 5494          Rotterdam  ...  proza                leerdicht
# 1164  Antwerpen/Brussel  ...  proza                 verhalen
# 1163  Antwerpen/Brussel  ...  proza  gedichten / dichtbundel
# 1162  Antwerpen/Brussel  ...  proza   tijdschrift / jaarboek
# ...                 ...  ...    ...                      ...
# 4477         Paramaribo  ...  proza                 verhalen
# 2965          Amsterdam  ...  proza               briefroman
# 2966          Amsterdam  ...  proza                vertaling
# 4326          Amsterdam  ...  proza                vertaling
# 4325          Amsterdam  ...  proza       non-fictie/brieven
#
#              geplaatst                           link naar DBNL.org author_id  \
# 5493  _alp001alph01_01  https://www.dbnl.org/tekst/_alp001alph01_01      None
# 5494  _alp001alph01_01  https://www.dbnl.org/tekst/_alp001alph01_01      None
# 1164  _alv001190001_01  https://www.dbnl.org/tekst/_alv001190001_01      None
# 1163  _alv001190001_01  https://www.dbnl.org/tekst/_alv001190001_01      None
# 1162  _alv001190001_01  https://www.dbnl.org/tekst/_alv001190001_01      None
# ...                ...                                          ...       ...
# 4477  zout002gesc01_01  https://www.dbnl.org/tekst/zout002gesc01_01   zout002
# 2965  zuyl002gesc01_01  https://www.dbnl.org/tekst/zuyl002gesc01_01   zuyl002
# 2966  zuyl002gesc01_01  https://www.dbnl.org/tekst/zuyl002gesc01_01   zuyl002
# 4326  zuyl002rebe01_01  https://www.dbnl.org/tekst/zuyl002rebe01_01   zuyl002
# 4325  zuyl002rebe01_01  https://www.dbnl.org/tekst/zuyl002rebe01_01   zuyl002
#
#      year_start  year_end  year_precision decade_start  decade_end
# 5493       1850      1860           circa         1850        1860
# 5494       1850      1860           circa         1850        1860
# 1164       1900      1901           exact         1900        1900
# 1163       1900      1901           exact         1900        1900
# 1162       1900      1901           exact         1900        1900
# ...         ...       ...             ...          ...         ...
# 4477       1980      1980           exact         1980        1980
# 2965       1942      1942           exact         1940        1940
# 2966       1942      1942           exact         1940        1940
# 4326       1978      1978           exact         1970        1970
# 4325       1978      1978           exact         1970        1970
#
# [2001 rows x 21 columns]

# %%
s = pub_df.subgenre.value_counts()
list(s[s > 10].index)
# Out:
# ['roman',
#  'tijdschrift / jaarboek',
#  'verhalen',
#  'novelle(n)',
#  'verzameld werk',
#  'historische roman',
#  'gedichten / dichtbundel',
#  'plaatwerk / prentenboek',
#  'non-fictie/essays-opstellen',
#  'schetsen',
#  'bloemlezing',
#  'reisbeschrijving',
#  'non-fictie/autobiografie-memoires',
#  'kroniek',
#  'kritiek(en)',
#  'detective',
#  'sprookje(s)',
#  'non-fictie/brieven',
#  'reisverhalen',
#  'column(s) / cursiefjes',
#  'non-fictie/theologie',
#  'briefroman',
#  'roman (populair/bestseller)',
#  'dierenverhaal/-epos',
#  'non-fictie/biografie',
#  'non-fictie/dagboek',
#  'aforismen',
#  'non-fictie/interview(s)',
#  'traktaat',
#  'satire',
#  'vertaling',
#  'studie',
#  'legende-mythe-sage',
#  'non-fictie/koloniën-reizen',
#  'marialegende',
#  'non-fictie/schoolboek',
#  'schelmenverhaal',
#  'lezing / voordracht',
#  'vertaling: Frans / Nederlands',
#  'limburg',
#  'non-fictie/geschiedenis-archeologie',
#  'bijbel / bijbeltekst(en)',
#  'vertaling: Amerikaans-Engels / Nederlands',
#  'proefschrift',
#  'heiligenleven',
#  'non-fictie/kunstgeschiedenis',
#  'toneeltekst (modern)',
#  'ridderroman',
#  'leerdicht',
#  'non-fictie/pamflet-brochure']

# %%
prose_fiction_genres = [
    'roman',
    'novelle(n)',
    'verhalen',
    'historische roman',
    'detective',
    'briefroman',
    'roman (populair/bestseller)',
    # 'dierenverhaal/-epos',
    # 'aforismen',
    # 'satire',
    # 'vertaling',
    # 'legende-mythe-sage',
    # 'marialegende',
    'schelmenverhaal',
    # 'vertaling: Frans / Nederlands',
    # 'bijbel / bijbeltekst(en)',
    # 'vertaling: Amerikaans-Engels / Nederlands',
    # 'heiligenleven',
    # 'toneeltekst (modern)',
    'ridderroman',
]

# %% [markdown]
# ## Removing anonymous titles and magazines

# %%
# if `Voornaam` is `Anoniem`, the author is anonymous
pub_df['is_anonymous'] = pub_df.voornaam.apply(lambda x: True if x == 'Anoniem' else False)
print(f"number of titles with anonymous authors: {len(pub_df[pub_df.is_anonymous == True])}")

# if the `ti_id` starts with an underscore, there is no seperate author ID
pub_df['no_author_id'] = pub_df.ti_id.str.startswith('_')
print(f"number of titles with no author ID: {len(pub_df[pub_df.no_author_id == True])}")

# if the `ti_id` starts with an underscore, there is no seperate author ID
pub_df['is_magazine'] = pub_df.subgenre.str.contains('tijdschrift')
print(f"number of titles that are magazines: {len(pub_df[pub_df.is_magazine == True])}")
# Out:
# number of titles with anonymous authors: 182
# number of titles with no author ID: 1514
# number of titles that are magazines: 1290

# %%
anonymous_ti_ids = list(pub_df[pub_df.is_anonymous == True].ti_id.unique())
authorless_ti_ids = list(pub_df[pub_df.no_author_id == True].ti_id.unique())
magazine_ti_ids = list(pub_df[pub_df.is_magazine == True].ti_id.unique())

remove_ids = list(set(anonymous_ti_ids + magazine_ti_ids + authorless_ti_ids))
print('number of title ids to remove:', len(remove_ids))
pub_df = pub_df[pub_df.ti_id.isin(remove_ids) == False]
pub_df.shape
# Out:
# number of title ids to remove: 1378
# (4146, 24)

# %%
pub_df = pub_df[(pub_df.is_anonymous == False) & (pub_df.no_author_id == False)]
s = pub_df.subgenre.value_counts()
s[s > 10]

# removing multi-author magazines/periodicals
pub_df = pub_df[pub_df.subgenre.apply(lambda x: False if 'tijdschrift' in x else True)]

# %%
pub_df.shape
# Out:
# (4146, 24)

# %% [markdown]
# ## Extra check: are there multiple print editions of a work?

# %%
pub_df[['ti_id', 'druk']].drop_duplicates().ti_id.value_counts()
# Out:
# ti_id
# kist001leve01    1
# butn001nood01    1
# eeml001scha02    1
# last001spaa02    1
# kool009scho01    1
#                 ..
# holt075scho01    1
# holt075broe01    1
# reyn008insh01    1
# reyn008mani01    1
# bosm029toch02    1
# Name: count, Length: 3168, dtype: int64

# %% [markdown]
# No, although for some titles we only have the second, third, or later print edition, for each work we only have one edition.

# %% [markdown]
# ## Removing titles with multiple authors

# %%
ti_auth = pub_df[['ti_id', 'voornaam', 'voorvoegsel', 'achternaam']].drop_duplicates()
num_authors = ti_auth.ti_id.value_counts()
multi_authors = num_authors[num_authors > 1]
pub_df[pub_df.ti_id.isin(multi_authors.index)]
# Out:
#               ti_id                                              titel  \
# 5     wolf016gesc01                     Geschrift eener bejaarde vrouw
# 6     wolf016gesc01                     Geschrift eener bejaarde vrouw
# 146   blom013iwei01  Iwein van Aelst (1128); Het blijspel van Mevro...
# 148   blom013iwei01  Iwein van Aelst (1128); Het blijspel van Mevro...
# 227   zegg002inde01                                    In de speeluren
# ...             ...                                                ...
# 5686  tien010scha01                             De schatten van Jantje
# 5687  tien010scha01                             De schatten van Jantje
# 5688  tien010scha01                             De schatten van Jantje
# 5713  groo050ondr01                       Ondrofeni sa leri ju: Tori's
# 5714  groo050ondr01                       Ondrofeni sa leri ju: Tori's
#
#           jaar       druk categorie voornaam voorvoegsel         achternaam  \
# 5         1802  1ste druk      werk    Betje         NaN              Wolff
# 6         1802  1ste druk      werk    Aagje         NaN              Deken
# 146       1842  1ste druk      werk   A.L.G.         NaN  Bosboom-Toussaint
# 148       1842  1ste druk      werk      Ph.         NaN          Blommaert
# 227       1850  1ste druk      werk   A.L.H.         NaN              Ising
# ...        ...        ...       ...      ...         ...                ...
# 5686  ca. 1943   2de druk   herdruk     A.B.         van          Tienhoven
# 5687  ca. 1943   2de druk   herdruk       A.         van          Tienhoven
# 5688  ca. 1943   2de druk   herdruk       A.         van          Tienhoven
# 5713  ca. 1950  1ste druk      werk   Antoon         NaN            Donicie
# 5714  ca. 1950  1ste druk      werk   A.H.P.          de              Groot
#
#              uitgever plaats_van_uitgave  ...  \
# 5     Isaac van Cleef           Den Hage  ...
# 6     Isaac van Cleef           Den Hage  ...
# 146               NaN                NaN  ...
# 148               NaN                NaN  ...
# 227       D.J. Couvee             Leyden  ...
# ...               ...                ...  ...
# 5686   Gebr. Kluitman            Alkmaar  ...
# 5687   Gebr. Kluitman            Alkmaar  ...
# 5688   Gebr. Kluitman            Alkmaar  ...
# 5713    Varekamp & Co         Paramaribo  ...
# 5714    Varekamp & Co         Paramaribo  ...
#
#                                link naar DBNL.org author_id year_start  \
# 5     https://www.dbnl.org/tekst/wolf016gesc01_01   wolf016       1802
# 6     https://www.dbnl.org/tekst/wolf016gesc01_01   wolf016       1802
# 146   https://www.dbnl.org/tekst/blom013iwei01_01   blom013       1842
# 148   https://www.dbnl.org/tekst/blom013iwei01_01   blom013       1842
# 227   https://www.dbnl.org/tekst/zegg002inde01_01   zegg002       1850
# ...                                           ...       ...        ...
# 5686  https://www.dbnl.org/tekst/tien010scha01_01   tien010       1943
# 5687  https://www.dbnl.org/tekst/tien010scha01_01   tien010       1943
# 5688  https://www.dbnl.org/tekst/tien010scha01_01   tien010       1943
# 5713  https://www.dbnl.org/tekst/groo050ondr01_01   groo050       1950
# 5714  https://www.dbnl.org/tekst/groo050ondr01_01   groo050       1950
#
#      year_end year_precision decade_start  decade_end  is_anonymous  \
# 5        1802          exact         1800        1800         False
# 6        1802          exact         1800        1800         False
# 146      1842          exact         1840        1840         False
# 148      1842          exact         1840        1840         False
# 227      1850          exact         1850        1850         False
# ...       ...            ...          ...         ...           ...
# 5686     1943          circa         1940        1940         False
# 5687     1943          circa         1940        1940         False
# 5688     1943          circa         1940        1940         False
# 5713     1950          circa         1950        1950         False
# 5714     1950          circa         1950        1950         False
#
#      no_author_id  is_magazine
# 5           False        False
# 6           False        False
# 146         False        False
# 148         False        False
# 227         False        False
# ...           ...          ...
# 5686        False        False
# 5687        False        False
# 5688        False        False
# 5713        False        False
# 5714        False        False
#
# [292 rows x 24 columns]

# %%
pub_df = pub_df[pub_df.ti_id.isin(multi_authors.index) == False]
pub_df.shape
# Out:
# (3854, 24)

# %% [markdown]
# ## Filtering prose fiction genres

# %%
non_prose_ids = pub_df[pub_df.subgenre.isin(prose_fiction_genres) == False].ti_id.unique()

# %%
non_prose_ids.shape
# Out:
# (1010,)

# %% [markdown]
# ### Collapsing subgenre labels
#
# Titles with multiple subgenres (where all subgenres are in our `prose_fiction_genres` list) have one row per subgenre. We want to merge the subgenres.

# %%
pub_df['is_prose'] = pub_df.ti_id.apply(lambda x: False if x in non_prose_ids else True)
pub_df.is_prose.value_counts()
# Out:
# is_prose
# True     2154
# False    1700
# Name: count, dtype: int64

# %%
#pub_df['is_prose'] = pub_df.subgenre.apply(lambda x: True if x in prose_fiction_genres else False)
#non_prose_ids = pub_df[pub_df.is_prose == False].ti_id.unique()
prose_df = pub_df[pub_df.is_prose]

#prose_df = pub_df[pub_df.subgenre.isin(prose_fiction_genres)]
pub_df.shape, prose_df.shape
# Out:
# ((3854, 25), (2154, 25))

# %%
prose_df = prose_df.drop('subgenre', axis=1).drop_duplicates()
prose_df.shape
# Out:
# (2069, 24)

# %% [markdown]
# Make sure that title IDs only occur once:

# %%
prose_df.ti_id.value_counts()
# Out:
# ti_id
# kist001leve01    1
# teir001mijn01    1
# liuw002jell01    1
# nijh002venu01    1
# noor022kanm01    1
#                 ..
# holt075scho01    1
# gogh002hoog01    1
# eman001mens01    1
# coen011eila02    1
# bosm029toch02    1
# Name: count, Length: 2069, dtype: int64

# %%
pub_df = pub_df.drop('subgenre', axis=1).drop_duplicates()
pub_df.to_csv('../metadata/DBNL-single_author_pub_titles.tsv', sep='\t', index=False)

# %%
prose_df.to_csv('../metadata/DBNL-single_author_prose_titles.tsv', sep='\t', index=False)
